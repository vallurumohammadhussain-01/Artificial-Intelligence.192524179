# %% [markdown]
# <a href="https://colab.research.google.com/github/vallurumohammadhussain-01/Artificial-Intelligence.192524179/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperature = int(input())
humidity = int(input())

if temperature > 35 and humidity > 60:
    print("Fan Speed High")
elif temperature > 35:
    print("Fan Speed Medium")
else:
    print("OFF")
# Out:
# 40
# 70
# Fan Speed High
